# %%
import pandas as pd
x = 5

# %%
df = pd.read_csv("L01_Working_with_pandas_data.csv")

# %%
df.iloc[2,2] = "big bones"

# %%
df.to_csv("new_table.csv")

# %%
df2 = pd.read_csv("new_table.csv")

# %%
df2
# Out:
#    Unnamed: 0  sample_num First_name  Last_name  Age  Weight_before  \
# 0           0           1      Jason     Miller   42            108
# 1           1           2      Molly   Jacobson   52             99
# 2           2           3       Tina  big bones   36            134
# 3           3           4       Jake     Milner   24            112
# 4           4           5        Amy      Cooze   73             95
# 5           5           6     Joshua      Dylan   25             71
# 6           6           7     Daniel     Wilson   53             94
# 7           7           8      Nancy       King   37             85
# 8           8           9       Ross      Evans   63             79
# 9           9          10      Miles       Bark   39            102
#
#    Weight_after
# 0            85
# 1            84
# 2            67
# 3            62
# 4            74
# 5            72
# 6            92
# 7            73
# 8            76
# 9            96

# %%
print(df2.shape[0])
# Out:
# 10

# %%
def printshit(df,first,last):
    return df.iloc[first:last,:]

# %%
x = printshit(df2,2,6)
x
# Out:
#    Unnamed: 0  sample_num First_name  Last_name  Age  Weight_before  \
# 2           2           3       Tina  big bones   36            134
# 3           3           4       Jake     Milner   24            112
# 4           4           5        Amy      Cooze   73             95
# 5           5           6     Joshua      Dylan   25             71
#
#    Weight_after
# 2            67
# 3            62
# 4            74
# 5            72
